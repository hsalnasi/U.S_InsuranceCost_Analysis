# %% [markdown]
# # U.S. Medical Insurance Costs

# %% [markdown]
# ## Introduction

# %% [markdown]
# The aim of this project is to see if there's a relationship between the average U.S insurance cost and other variables such as `(age - status - health )`.
# **The Dataset used in this project** is a CSV file **insuarnce.csv** which contains informations about several U.S citizens's insurance informations

# %% [markdown]
#  ### importing libraries and helper functions

# %% [markdown]
# - importing libraries and loading the dataset
# -Creating a helper function to edit any errors in the dataset easily .

# %%
 # using pandas to read our file eaisly.
import pandas as pd
import csv

# importing seaborn to create creative visualizations 
import seaborn as sb
# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.style.use('tableau-colorblind10')
plt.style.use('tableau-colorblind10')

# %% [markdown]
# *building a helper function to help us edit any missing values or errors in our data*

# %%
# create a function to handle any errors in capitalization
def edit_naming(dataframe): 
    edited_columns = []
    for column in dataframe.columns:
        column = column.title()
        edited_columns.append(column)
        
    dataframe.columns = edited_columns
        
    return dataframe
        
# create a function to round any decimal values to be float64 .
def round_column(dataframe, column,digit):
    rounded_lst = []
    # round the decimals
    for num in dataframe[column]:
        if isinstance(digit,int) and digit >= 0:
            num = round(num,digit)
           
        elif digit == 'None':
            num = round(num)
            
        rounded_lst.append(num)
    
    dataframe[column] = rounded_lst
    
    return dataframe

# add a symbol to the desiered column
def add_symbol(symbol,dataframe,column): 
    dataframe[column] = symbol + dataframe[column].astype(str)
    
    return dataframe

# %% [markdown]
# ## - Load the dataset and handle it using pandas -
# Next step , navigating into the dataset looking for any errors or miss handleed infos such as (NA values)

# %%
# read the csv file 
df = pd.read_csv('insurance.csv')
df.head(20)
# create a data frame containing our dataset
df = pd.DataFrame(df)

# %% [markdown]
# after reading the data , it can be noticed that the data contains errors and bad naming methods (bad capitalization).

# %% [markdown]
# ## clean and organize data

# %%
#edit the capitalization from small letters -> title 
df = edit_naming(df)

# print our new modified columns 
df
# Out:
#       Age     Sex     Bmi  Children Smoker     Region      Charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
#  The columns now has a camel case titles.

# %%
# using our helper function we will round charges column and add $ symbol to indicate whenever there's a currency
round_column(df,'Charges','None')
add_symbol('$',df,'Charges')

round_column(df,'Bmi',2)
# testing to see if any changes were made in the Charges column
df
# Out:
#       Age     Sex    Bmi  Children Smoker     Region Charges
# 0      19  female  27.90         0    yes  southwest  $16885
# 1      18    male  33.77         1     no  southeast   $1726
# 2      28    male  33.00         3     no  southeast   $4449
# 3      33    male  22.70         0     no  northwest  $21984
# 4      32    male  28.88         0     no  northwest   $3867
# ...   ...     ...    ...       ...    ...        ...     ...
# 1333   50    male  30.97         3     no  northwest  $10601
# 1334   18  female  31.92         0     no  northeast   $2206
# 1335   18  female  36.85         0     no  southeast   $1630
# 1336   21  female  25.80         0     no  southwest   $2008
# 1337   61  female  29.07         0    yes  northwest  $29141
#
# [1338 rows x 7 columns]

# %% [markdown]
# ##  - Exploratiary Data Analysis -

# %% [markdown]
#  #### After cleaning and organizing  Data , next is to make investigations and relate some relations in the dataset.
#
#  - after cleaning the data , some of the queries conducted:
#       - what is the relationship between age and cost ?
#       - is there is any gender specific relationship ?
#       - number of smokers and none smokers
#
#  `in order to answer the above questions , we will need to investigate the following :`
#          - What is the average smokers in the data set ?
#          - How much is the female:male ratio in regards of patients ? detect bias if there's any
#          - What is the average cost in general ?

# %%
# start by exploring our data frame 
df.info()

df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       1338 non-null   int64
#  1   Sex       1338 non-null   object
#  2   Bmi       1338 non-null   float64
#  3   Children  1338 non-null   int64
#  4   Smoker    1338 non-null   object
#  5   Region    1338 non-null   object
#  6   Charges   1338 non-null   object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 73.3+ KB
#                 Age   Sex          Bmi     Children Smoker     Region Charges
# count   1338.000000  1338  1338.000000  1338.000000   1338       1338    1338
# unique          NaN     2          NaN          NaN      2          4    1294
# top             NaN  male          NaN          NaN     no  southeast  $11658
# freq            NaN   676          NaN          NaN   1064        364       3
# ...

# %%
# get average age
average_age = df['Age'].mean()
print(f'Average Age : {average_age}')

# number of females
females = df['Sex'].value_counts()['female']
print(f'according to our dataset ,we have {females} females patients.')

# num of males
males = df['Sex'].value_counts()['male']
print(f'according to our dataset ,we have {males} males patients.')    

# male : female ratio
male_female_ratio = males - females
print(f' Female:Male ratio: 0:{male_female_ratio}')

# num of females smoker vs num of male smokers
female_smoker = df[(df['Sex'] == 'female') & (df['Smoker'] == 'yes')]
male_smoker = df[(df['Sex'] == 'male') & (df['Smoker'] == 'yes')]

# non-smoker female 
nonsmoker_female = df[(df['Sex'] == 'female') & (df['Smoker'] == 'no')]
nonsmoker_male = df[(df['Sex'] == 'male') & (df['Smoker'] == 'no')]

# average cost of a medical insurance 
edit_cost =  df['Charges'].str.replace('$','').astype(float)
average_cost = round(edit_cost).mean()

print(f'\nThe average cost of a medical insurance :{round(average_cost)}$')
# Out:
# Average Age : 39.20702541106129
# according to our dataset ,we have 662 females patients.
# according to our dataset ,we have 676 males patients.
#  Female:Male ratio: 0:14
#
# The average cost of a medical insurance :13270$

# %% [markdown]
# ### Visualize results

# %%
#female_smoker['Charges'] = female_smoker['Charges'].str.replace('$','').astype('float64')

#         ---------------------------------FEMALE --------------------------------
dfFemale_smoker = female_smoker
#dfFemale_smoker.drop(['Smoker', 'Sex'],axis=1, inplace=True)
#dfFemale_smoker.drop(['Bmi', 'Children', 'Region'], axis=1, inplace=True)


fig,axs = plt.subplots(ncols=4,figsize=(35,8))


plt.title('Female smokers age vs Insuarnce cost')
sb.histplot(data=dfFemale_smoker, x='Charges', y='Age',ax=axs[0])
plt.xlabel('Cost')
plt.ylabel('Age')
axs[0].set_title('Female smokers age vs Insuarnce cost')
# plotting non-smokers to compare the results
dfFemale_nonsmoker = nonsmoker_female
#dfFemale_nonsmoker['Charges'] = dfFemale_nonsmoker['Charges'].str.replace('$','').astype('float64')
#dfFemale_nonsmoker.drop(['Bmi', 'Children', 'Region','Sex', 'Smoker'], axis=1, inplace=True)

plt.title('Female non-smokers age vs Insuarnce cost')
sb.histplot(data=dfFemale_nonsmoker, x='Charges', y='Age', kde=True, ax=axs[1])
plt.xlabel('Cost')
plt.ylabel('Age')
axs[1].set_title('Female non-smokers age vs Insuarnce cost')
#        ------------------------- MALES -------------------------------------------
#nonsmoker_male['Charges'] = nonsmoker_male['Charges'].str.replace('$','').astype('float64')
#male_smoker['Charges'] = male_smoker['Charges'].str.replace('$','').astype('float64')

#nonsmoker_male.drop(['Bmi', 'Sex', 'Children', 'Smoker','Region'],axis=1,inplace=True)

#male_smoker.drop(['Bmi', 'Sex', 'Children', 'Smoker','Region'], axis=1,inplace=True)

dfMale_smoker = nonsmoker_male
dfMale_nonsmoker = male_smoker


plt.title('Male smokers Age vs Insuarnce Cost')
sb.histplot(data=dfMale_smoker, x='Charges', y='Age', ax=axs[2])
plt.xlabel('Cost')
plt.ylabel('Age')
axs[2].set_title('Male smokers Age vs Insuarnce Cost')

plt.title('Male None-Smokers Age vs Insuarnce Cost')
sb.histplot(data=dfMale_nonsmoker, x='Charges', y='Age', ax=axs[3])
plt.xlabel('Cost')
plt.ylabel('Age')


plt.show()


results_df = pd.DataFrame(data={
    'MAX cost Female-nonsmoker-':dfFemale_nonsmoker.max(),
      'MIN cost Female-nonsmoker-':dfFemale_nonsmoker.min(),
       'MAX cost Female-smoekr-': dfFemale_smoker.max(),
         'MIN cost Female-smoker-': dfFemale_smoker.min(),
          ' MAX cost - Male NonesSmoker-': dfMale_nonsmoker.max(),
            'MIN cost - Male NoneSmoker-':dfMale_nonsmoker.min(),
            'MAX cost -Male Smoker-': dfMale_smoker.max(),
            'MIN cost -Male Smoker': dfMale_smoker.min()})

results_df.head()

#print(plt.style.available)
# Out:
#          MAX cost Female-nonsmoker-  MIN cost Female-nonsmoker-  \
# Age                            64.0                        18.0
# Charges                     36911.0                      1608.0
#
#          MAX cost Female-smoekr-  MIN cost Female-smoker-  \
# Age                         64.0                     18.0
# Charges                  63770.0                  13845.0
#
#           MAX cost - Male NonesSmoker-  MIN cost - Male NoneSmoker-  \
# Age                               64.0                         18.0
# Charges                        62593.0                      12829.0
#
#          MAX cost -Male Smoker-  MIN cost -Male Smoker
# Age                        64.0                   18.0
# Charges                 32109.0                 1122.0

# %% [markdown]
# #### According to to the Dataset , Age , Gender , and healthstatus(Smoker, None-smoker) are some of the factors to determine the Cost per indivisual .
#
# - When comparing the Female smoker vs None smoker age vs Cost , the following was noticed :
#     - The most expensive insurance costs `+3000 $`for a 64 years old None-smoker Female.
#     - On the other hand , for a the smoker female we found that the top expensive insurance was around`+60000 $`
#
# Thus its obvious that:
#
#     The older , the more expensive the insurance.
#     The American non smoker female has less costly insurance than the American female who smokes
# same observation was made to Male smaples :
#  - the 64 years smoker man will have to pay around `32109.0$` unlike the 18 years old male smoker `1122.0$`
#  - nonesmoker male will have to pay less `62593.0$` for a 64 years old male and `12829.0$` for a 18 years old male
#
# noting that the male has to pay around `14000$` more depending on the age and health status.

# %% [markdown]
# ### -comparing number of Children of individuals and Insurance costs-
#  in this section all data are read from the csv file and made into a list of dictionaries , then individuals are divided based on the number of children they have and average insurance cost of each group is calculated and printed
#  at the end a dictionary containing the number of people in each category and their average insurance cost is saved in a dictionary called child_data

# %%
with open('insurance.csv' , newline='') as insurance_data:
    data = list(csv.DictReader(insurance_data))

def child_analysis():
    #in this section categories are created based on the number of children
    #and based on these categories number of individuals and their costs are saved in children_count and children_cost respectively
    children_count = {}
    children_cost = {}
    for individual in data:
        x = individual['children']
        if x in children_count :
            children_count[x] += 1
        else :
            children_count[x] = 1
        if x in children_cost :
            children_cost[x] += round(float(individual['charges']))
        else :
            children_cost[x] = round(float(individual['charges']))


    #in this section keys and values of the children_cost dictionary are made into lists along side with the number of individuals in different variables
    #a loop is created that goes through the list of children_cost keys meaning it goes through each category of individuals and calculates the average 
    #cost of each category's insurance cost
    child_index_cost_value = list(children_cost.values())
    child_index_cost_keys = list(children_cost.keys())
    child_index_count = list(children_count.values())
    count = 0
    for individual in child_index_cost_keys:
        children_cost[individual] = round(float(child_index_cost_value[count] / child_index_count[count]))
        count += 1

    #finally a list is created that each catrgory is saved into a dictionary and appended to that list called child_data
    child_index_cost_value = list(children_cost.values())
    child_data = []
    for i in range(len(child_index_cost_keys)):
        print ('there are' , child_index_count[i] , 'people with' , child_index_cost_keys[i] , 'number of children that have' , child_index_cost_value[i] , 'average of insurance expenses')
        child_data.append({'children number category':int(child_index_cost_keys[i]) , 'individuals':child_index_count[i] , 'average cost':child_index_cost_value[i]})
    
    #visulaize the results.
    x_axis = [i['children number category'] for i in child_data]
    y_axis = [i['average cost'] for i in child_data]

    with plt.style.context('seaborn-white'): 
        plt.bar(x_axis, y_axis)
        plt.title('Cost compared to num of children',)
      
        plt.xlabel('Number of Children')
        plt.ylabel('Average Insurance Expenses')
        plt.show()

    #plt.scatter(x_axis, y_axis, c=x_axis)
    
child_analysis()
# Out:
# there are 574 people with 0 number of children that have 12366 average of insurance expenses
# there are 324 people with 1 number of children that have 12731 average of insurance expenses
# there are 157 people with 3 number of children that have 15355 average of insurance expenses
# there are 240 people with 2 number of children that have 15074 average of insurance expenses
# there are 18 people with 5 number of children that have 8786 average of insurance expenses
# there are 25 people with 4 number of children that have 13851 average of insurance expenses

# %% [markdown]
# ### Detecting bias in the Dataset

# %%
df['Sex'].describe(include='all')
# Out:
# count     1338
# unique       2
# top       male
# freq       676
# Name: Sex, dtype: object

# %% [markdown]
# ##### Looking back to the *Female:Male* ratio and the domenating gender among the dataset , It is clear that there is a male bias in the data gathered .
#
# *The following Graph will visualize how male samples overweighted the female samples in the dataset*

# %%
plt.title('Comparing Females number vs Males numbers')
sb.histplot(data=df['Sex'], bins=3)

plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The goal of this project was to detect a relationship between The U.S Insurance Cost and factors such as `(Age-health status - Gender)` .
# a *CSV* file containing the dataset has been cleaned and observeed. The average age was 39 years old and the oldest patient is 64 years old while the youngest is 18 years old for both genders .
# It was also noticed that depending on health status(smoker,non-smoker) and age, the price can varies. The non-smoker male at the Age 64 can pay around `	62593$` for insurance while a 18 years old male would have to pay much less around `12829$` maming the diffrence 49,764$, while on the other hand if the indivisual is smoker, he will have to pay `32109.0$` more. pointing the fact that price is depending on Age and health status.
# The same observation was made on female samples.
#
# There has ben a bias detected in the data gathered , femlaes smaples were missing 14 indivisual compared to the males.
